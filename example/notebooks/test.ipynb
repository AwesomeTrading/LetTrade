# %%
import talib.abstract as ta

from lettrade import DataFeed, LetTrade, Strategy
from lettrade.indicator import crossover


class SmaCross(Strategy):
    ema1_period = 9
    ema2_period = 21

    def init(self):
        pass

    def indicators(self, df: DataFeed):
        df["ema1"] = ta.EMA(df, timeperiod=self.ema1_period)
        df["ema2"] = ta.EMA(df, timeperiod=self.ema2_period)

        self.sma1 = df["ema1"]
        self.sma2 = df["ema2"]

        return df

    def next(self, df):
        if crossover(self.sma1, self.sma2):
            self.buy(1)
        elif crossover(self.sma2, self.sma1):
            self.sell(1)

    def end(self):
        print("*" * 64)
        print(self.data.tail(10))


lt = LetTrade(
    strategy=SmaCross,
    csv="data/EURUSD=X.csv",
)

lt.run()
# Out:
# ****************************************************************
#       datetime      open      high       low     close  Adj Close  volume  \
# -9  2023-12-18  1.089526  1.093004  1.089455  1.089526   1.089526       0
# -8  2023-12-19  1.092383  1.098800  1.091608  1.092383   1.092383       0
# -7  2023-12-20  1.098105  1.097972  1.093565  1.098105   1.098105       0
# -6  2023-12-21  1.094571  1.099977  1.093625  1.094571   1.094571       0
# -5  2023-12-22  1.100619  1.104057  1.099421  1.100619   1.100619       0
# -4  2023-12-25  1.102657  1.104240  1.099989  1.102657   1.102657       0
# -3  2023-12-26  1.102026  1.103997  1.100958  1.102026   1.102026       0
# -2  2023-12-27  1.104301  1.112248  1.102925  1.104301   1.104301       0
# -1  2023-12-28  1.110864  1.113945  1.107101  1.110864   1.110864       0
#  0  2023-12-29  1.106819  1.108647  1.104326  1.106819   1.106819       0
#
#         ema1      ema2
# -9  1.086722  1.084514
# -8  1.087854  1.085229
# -7  1.089904  1.086400
# -6  1.090838  1.087142
# -5  1.092794  1.088368
# -4  1.094767  1.089667
# -3  1.096218  1.090790
# -2  1.097835  1.092018
# -1  1.100441  1.093732
#  0  1.101716  1.094921

# %%
lt.plot()

# %%
lt.data[0]
